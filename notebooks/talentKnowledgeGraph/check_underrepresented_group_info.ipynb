# %%
import pandas as pd
authors_b2ai = pd.read_csv('/data/jx4237data/TKG/TKG_JCDL/Bridge2AI_10k/Authors.csv')

# %%
authors_b2ai['Race'].value_counts()
# Out:
# Race
# white       31170
# api         10393
# hispanic     2749
# black         361
# Name: count, dtype: int64

# %%
authors_b2ai[authors_b2ai['CM4AI'] == 1]['Race'].value_counts()
# Out:
# Race
# white    21
# api       3
# Name: count, dtype: int64

# %%
authors_b2ai[authors_b2ai['CM4AI'] == 1]
# Out:
#                   AID                               FullName  BeginYear  \
# 3                1098                Vardit Ravitsky (CM4AI)       2002
# 1275           506431               Sami Nourreddine (CM4AI)       2016
# 1425        100000022                   Jake Y. Chen (CM4AI)       2003
# 3380          1306796             Christopher Churas (CM4AI)       2002
# 5604          2143034               Kirsten Obernier (CM4AI)       2009
# 7691          2936544          Richard Andrew Taylor (CM4AI)       2003
# 7982        100000109            Pamela Payne Foster (CM4AI)       2007
# 8961          3410248                  Emma Lundberg (CM4AI)       2007
# 10951         4161500                  Prashant Mali (CM4AI)       2004
# 12366       100000067              Sarah J Ratcliffe (CM4AI)       1998
# 12628         4802195  Jean-Christophe Belisle-Pipon (CM4AI)       2012
# 12967       100000114                   Aidong Zhang (CM4AI)       1987
# ...

# %%
authors_b2ai['CM4AI'].value_counts()
# Out:
# CM4AI
# 1.0    34
# Name: count, dtype: int64
